# %%
# **TESTE DE ESTACIONARIDADE**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %% [markdown]
# ## Criação da Série

# %%
np.random.seed(10)
dados1 = np.random.normal(0,1,41)
dados1
# Out:
# array([ 1.3315865 ,  0.71527897, -1.54540029, -0.00838385,  0.62133597,
#        -0.72008556,  0.26551159,  0.10854853,  0.00429143, -0.17460021,
#         0.43302619,  1.20303737, -0.96506567,  1.02827408,  0.22863013,
#         0.44513761, -1.13660221,  0.13513688,  1.484537  , -1.07980489,
#        -1.97772828, -1.7433723 ,  0.26607016,  2.38496733,  1.12369125,
#         1.67262221,  0.09914922,  1.39799638, -0.27124799,  0.61320418,
#        -0.26731719, -0.54930901,  0.1327083 , -0.47614201,  1.30847308,
#         0.19501328,  0.40020999, -0.33763234,  1.25647226, -0.7319695 ,
#         0.66023155])

# %%
dados1 = pd.DataFrame(dados1)
dados1.head()
# Out:
#           0
# 0  1.331587
# 1  0.715279
# 2 -1.545400
# 3 -0.008384
# 4  0.621336

# %%
dados1.columns = ['valores']
dados1.head()
# Out:
#     valores
# 0  1.331587
# 1  0.715279
# 2 -1.545400
# 3 -0.008384
# 4  0.621336

# %%
dados1.shape
# Out:
# (41, 1)

# %%
indice = pd.date_range('1980', periods = len(dados1), freq = 'Y')
indice
# Out:
# DatetimeIndex(['1980-12-31', '1981-12-31', '1982-12-31', '1983-12-31',
#                '1984-12-31', '1985-12-31', '1986-12-31', '1987-12-31',
#                '1988-12-31', '1989-12-31', '1990-12-31', '1991-12-31',
#                '1992-12-31', '1993-12-31', '1994-12-31', '1995-12-31',
#                '1996-12-31', '1997-12-31', '1998-12-31', '1999-12-31',
#                '2000-12-31', '2001-12-31', '2002-12-31', '2003-12-31',
#                '2004-12-31', '2005-12-31', '2006-12-31', '2007-12-31',
#                '2008-12-31', '2009-12-31', '2010-12-31', '2011-12-31',
#                '2012-12-31', '2013-12-31', '2014-12-31', '2015-12-31',
#                '2016-12-31', '2017-12-31', '2018-12-31', '2019-12-31',
#                '2020-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
serie1 = pd.Series(dados1['valores'].values, index = indice)

# %%
serie1.plot()
plt.show()

# %% [markdown]
# ## **TESTES DE ESTACIONARIDADE**

# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.0-cp39-cp39-win_amd64.whl (9.4 MB)
#      ---------------------------------------- 9.4/9.4 MB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18 in c:\users\sergio\appdata\roaming\python\python39\site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\users\sergio\appdata\roaming\python\python39\site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: pandas>=1.0 in c:\users\sergio\appdata\roaming\python\python39\site-packages (from statsmodels) (1.5.3)
# Collecting patsy>=0.5.2 (from statsmodels)
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ---------------------------------------- 233.8/233.8 kB ? eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in c:\users\sergio\appdata\roaming\python\python39\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sergio\appdata\roaming\python\python39\site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sergio\appdata\roaming\python\python39\site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sergio\appdata\roaming\python\python39\site-packages (from pandas>=1.0->statsmodels) (2022.7.1)
# Requirement already satisfied: six in c:\users\sergio\appdata\roaming\python\python39\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.3 statsmodels-0.14.0

# %%
import statsmodels.tsa.stattools

# %% [markdown]
# Teste KPSS (Kwiatkowski-Phillips-Schmidt-Shin)
#
# Ho = não é estacionário: estatística do teste > valor crítico
#
# Ha = é estacionário:  estatística do teste < valor crítico

# %%
statsmodels.tsa.stattools.kpss(serie1)
# Out:
# C:\Users\Sergio\AppData\Local\Temp\ipykernel_9808\419759984.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   statsmodels.tsa.stattools.kpss(serie1)
# (0.0685962789581985,
#  0.1,
#  0,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %%
kpss = statsmodels.tsa.stattools.kpss(serie1)
print('Estatítica do teste: {:.4f}'.format(kpss[0]))
print('p_valor: {:.4f}'.format(kpss[1]))
print('número de lags: {}'.format(kpss[2]))
print('Valores Críticos:')
for chave, valor in kpss[3].items():
   print('{}: {:.4f}'.format(chave, valor))
# Out:
# Estatítica do teste: 0.0686
# p_valor: 0.1000
# número de lags: 0
# Valores Críticos:
# 10%: 0.3470
# 5%: 0.4630
# 2.5%: 0.5740
# 1%: 0.7390
# C:\Users\Sergio\AppData\Local\Temp\ipykernel_9808\3108268961.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss = statsmodels.tsa.stattools.kpss(serie1)

# %% [markdown]
# Teste df (Dickey Fuller)
#
# Ho = não é estacionário: estatística do teste > valor crítico
#
# Ha = é estacionário:  estatística do teste < valor crítico

# %%
df = statsmodels.tsa.stattools.adfuller(serie1)
print('Estatítica do teste: {:.4f}'.format(df[0]))
print('p_valor: {:.8f}'.format(df[1]))
print('Valores Críticos:')
for chave, valor in df[4].items():
   print('{}: {:.4f}'.format(chave, valor))
# Out:
# Estatítica do teste: -5.8642
# p_valor: 0.00000034
# Valores Críticos:
# 1%: -3.6056
# 5%: -2.9371
# 10%: -2.6070

# %% [markdown]
# **AirPassengers: dados clássicos da companhia aérea Box & Jenkins. Totais mensais de passageiros de companhias aéreas internacionais, 1949 a 1960.**

# %%
serie2 = pd.read_csv('D:/Python/Series_Temporais/AirPassengers.csv')

# %%
serie2
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
serie2 = pd.Series(serie2['#Passengers'].values, index = serie2['Month'])
serie2
# Out:
# Month
# 1949-01    112
# 1949-02    118
# 1949-03    132
# 1949-04    129
# 1949-05    121
#           ...
# 1960-08    606
# 1960-09    508
# 1960-10    461
# 1960-11    390
# 1960-12    432
# Length: 144, dtype: int64

# %%
serie2.plot()
plt.show()

# %% [markdown]
# ## **TESTES DE ESTACIONARIDADE**

# %%
import statsmodels.tsa.stattools

# %% [markdown]
# Teste KPSS (Kwiatkowski-Phillips-Schmidt-Shin)
#
# Ho = não é estacionário: estatística do teste > valor crítico
#
# Ha = é estacionário:  estatística do teste < valor crítico

# %%
kpss2 = statsmodels.tsa.stattools.kpss(serie2)
print('Estatítica do teste: {:.4f}'.format(kpss2[0]))
print('p_valor: {:.4f}'.format(kpss2[1]))
print('Valores Críticos:')
for chave, valor in kpss2[3].items():
   print('{}: {:.4f}'.format(chave, valor))
# Out:
# Estatítica do teste: 1.6513
# p_valor: 0.0100
# Valores Críticos:
# 10%: 0.3470
# 5%: 0.4630
# 2.5%: 0.5740
# 1%: 0.7390
# C:\Users\Sergio\AppData\Local\Temp\ipykernel_9808\2987356545.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss2 = statsmodels.tsa.stattools.kpss(serie2)

# %% [markdown]
# ### Não estacionaria

# %% [markdown]
# Teste df (Dickey Fuller)
#
# Ho = não é estacionário: estatística do teste > valor crítico
#
# Ha = é estacionário:  estatística do teste < valor crítico

# %%
df2 = statsmodels.tsa.stattools.adfuller(serie2)
print('Estatítica do teste: {:.4f}'.format(df2[0]))
print('p_valor: {:.8f}'.format(df2[1]))
print('Valores Críticos:')
for chave, valor in df2[4].items():
   print('{}: {:.4f}'.format(chave, valor))
# Out:
# Estatítica do teste: 0.8154
# p_valor: 0.99188024
# Valores Críticos:
# 1%: -3.4817
# 5%: -2.8840
# 10%: -2.5788

# %% [markdown]
# ### Não estacionaria
